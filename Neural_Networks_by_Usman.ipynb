# %% [markdown]
# # **TechnoHacks Machine Learning Internship**
# ---
# #**By: Muhammad Usman**
# ---
# #**Task 09: Neural Network Basics**

# %% [markdown]
# ###**Importing Important Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ###**Loading and Splitting of dataset, that is Already Availabe in keras**

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ###**Preprocessing the data, Normalizing and Categorizing**

# %%
x_train=x_train/255.0
x_test=x_test/255.0

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

# %% [markdown]
# ###**Creating a simple Neural Network wwith three layers of function**

# %%
model=Sequential()
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ###**Compiling the created Model**

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ###**Main Step: Feeding and Training the model with provided data**

# %%
history=model.fit(x_train,y_train,epochs=10,validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.5593 - loss: 1.6528 - val_accuracy: 0.8640 - val_loss: 0.5707
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8659 - loss: 0.5217 - val_accuracy: 0.8957 - val_loss: 0.3944
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.8945 - loss: 0.3870 - val_accuracy: 0.9068 - val_loss: 0.3400
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9026 - loss: 0.3457 - val_accuracy: 0.9122 - val_loss: 0.3125
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9096 - loss: 0.3185 - val_accuracy: 0.9167 - val_loss: 0.2953
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9140 - loss: 0.2993 - val_accuracy: 0.9175 - val_loss: 0.2819
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9168 - loss: 0.2898 - val_accuracy: 0.9207 - val_loss: 0.2735
# Epoch 8/10
# ...

# %% [markdown]
# ###**Evaluating: Checking Loss and Accuracy Score**

# %%
test_loss,test_accuracy=model.evaluate(x_test,y_test)
print("Test accuracy:",test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9176 - loss: 0.2822
# Test accuracy: 0.9283000230789185

# %% [markdown]
# #**Plotting The Loss and Accuracy Score**

# %%
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
